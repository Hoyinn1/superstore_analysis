# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
  table = pd.read_excel("BikeSales.xlsx", header=1)

# %%
# load data into database
table.head()
# Out:
#    Unnamed: 0 Unnamed: 1      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN        NaN             NaN        NaN        NaN        NaN
# 1         NaN         ID  Marital Status     Gender     Income   Children
# 2         NaN      12496         Married     Female      40000          1
# 3         NaN      24107         Married       Male      30000          3
# 4         NaN      14177         Married       Male      80000          5
#
#         Unnamed: 6      Unnamed: 7  Unnamed: 8 Unnamed: 9       Unnamed: 10  \
# 0              NaN             NaN         NaN        NaN               NaN
# 1        Education      Occupation  Home Owner       Cars  Commute Distance
# 2        Bachelors  Skilled Manual         Yes          0         0-1 Miles
# 3  Partial College        Clerical         Yes          1         0-1 Miles
# 4  Partial College    Professional          No          2         2-5 Miles
#
#   Unnamed: 11 Unnamed: 12     Unnamed: 13
# ...

# %%
table.tail(11)
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 991          NaN      29134    Married       Male      60000          4
# 992          NaN      14332     Single     Female      30000          0
# 993          NaN      19117     Single     Female      60000          1
# 994          NaN      22864    Married       Male      90000          2
# 995          NaN      11292     Single       Male     150000          1
# 996          NaN      13466    Married       Male      80000          5
# 997          NaN      23731    Married       Male      60000          2
# 998          NaN      28672     Single       Male      70000          4
# 999          NaN      11809    Married       Male      60000          2
# 1000         NaN      19664     Single       Male     100000          3
# 1001         NaN      12121     Single       Male      60000          3
#
#            Unnamed: 6      Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# ...

# %%
table.describe()
# Out:
#        Unnamed: 0
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 table.dtypes()
#
# TypeError: 'Series' object is not callable
